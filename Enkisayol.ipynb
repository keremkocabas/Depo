# %%
import networkx as nx
import matplotlib.pyplot as plt

# Grafı oluşturuyoruz
G = nx.Graph()

# Düğüm (node) ve kenar (edge) ekliyoruz
# G.add_edge(node1, node2, weight=edge_weight)
G.add_edge('A', 'B', weight=6)
G.add_edge('A', 'D', weight=1)
G.add_edge('B', 'C', weight=5)
G.add_edge('B', 'E', weight=2)
G.add_edge('C', 'F', weight=8)
G.add_edge('D', 'B', weight=2)
G.add_edge('D', 'E', weight=6)
G.add_edge('E', 'F', weight=3)

# Dijkstra algoritmasını kullanarak en kısa yolu buluyoruz
shortest_path = nx.dijkstra_path(G, source='A', target='F', weight='weight')
shortest_distance = nx.dijkstra_path_length(G, source='A', target='F', weight='weight')

# Sonuçları yazdırıyoruz
print("En kısa yol:", shortest_path)


# Grafı çiziyoruz
pos = nx.spring_layout(G)  # Düğümlerin yerleşimini belirler
plt.figure(figsize=(8, 6))

# Grafı çiziyoruz
nx.draw(G, pos, with_labels=True, node_size=3000, node_color="lightblue", font_size=15, font_weight="bold", edge_color='gray')

# Kenarların ağırlıklarını yazdırıyoruz
edge_labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

# En kısa yolu çiziyoruz
path_edges = list(zip(shortest_path, shortest_path[1:]))
nx.draw_networkx_edges(G, pos, edgelist=path_edges, edge_color='red', width=2)

# Grafı gösteriyoruz
plt.title("Graf ve En Kısa Yol (A'dan F'ye)")
plt.show()
# Out:
# En kısa yol: ['A', 'D', 'B', 'E', 'F']
